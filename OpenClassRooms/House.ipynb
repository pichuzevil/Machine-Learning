# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
csv_path = os.path.join(r'C:\Users\Pierre\Desktop\Bases de données\OpenClassRooms', "house.csv")
house_data = pd.read_csv(csv_path)

plt.plot(house_data['surface'], house_data['loyer'], 'ro', markersize=4)

# %%
# On décompose le dataset et on le transforme en matrices pour pouvoir effectuer notre calcul
X = np.matrix([np.ones(house_data.shape[0]), house_data['surface'].values]).T
y = np.matrix(house_data['loyer']).T

# On effectue le calcul exact du paramètre theta
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

print(theta)
# Out:
# [[-283.37836117]
#  [  40.97116431]]

# %%
plt.plot(house_data['surface'], house_data['loyer'], 'ro', markersize=4)
plt.plot([0,250], [theta.item(0),theta.item(0) + 250 * theta.item(1)], linestyle='--', c='#000000')

# %%
from sklearn.model_selection import train_test_split #Scikit-Learn provides a few functions to split datasets
#into multiple subsets in various ways.

train_set, test_set = train_test_split(house_data, test_size=0.2, random_state=42)
test_set
# Out:
#      loyer  surface
# 316   1750       51
# 77    2000       53
# 360   3200      105
# 90    2200       50
# 493   1250       31
# ..     ...      ...
# 15     815       20
# 357   3200      114
# 39    1445       46
# 54    1700       60
# 155   6000      152
#
# [109 rows x 2 columns]
